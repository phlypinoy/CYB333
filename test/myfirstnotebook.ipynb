# %% [markdown]
# # My First Notebook

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# # Section 1

# %% [markdown]
# # Section 2

# %% [markdown]
# # Product Analysis

# %%
import numpy as np
np.random.randint(0, 10, size=(3, 3))
# Out:
# array([[9, 2, 9],
#        [2, 5, 2],
#        [8, 9, 1]])

# %%
import sys, os
print("Python executable:", sys.executable)
print("CWD:", os.getcwd())
# Out:
# Python executable: /home/phly/Documents/CYB333/.conda/bin/python
# CWD: /home/phly/Documents/CYB333/test
# Python version: 3.11.14 (main, Oct 21 2025, 18:31:21) [GCC 11.2.0]
# Platform: posix posix.uname_result(sysname='Linux', nodename='GentooThinkpad', release='6.12.54-gentoo-dist', version='#1 SMP PREEMPT_DYNAMIC Sun Oct 19 17:24:08 -00 2025', machine='x86_64')
# PID: 4081
# File path: /tmp/ipykernel_4081/2774933963.py
# Absolute: /tmp/ipykernel_4081/2774933963.py
# Exists: False
#
# --- Current directory: /home/phly/Documents/CYB333/test ---
# copilot_test.js 2878 bytes
# myfirstnotebook.ipynb 2130 bytes
# README.md 811 bytes
# test.py 217 bytes
#
# Environment variables (count): 79
# USER: phly
# HOME: /home/phly
# SHELL: /usr/bin/zsh
# PATH: /home/phly/Documents/CYB333/.conda/bin:/home/phly/miniconda3/condabin:/usr/local/sbin:/usr/local/bin:/usr/bin:/opt/bin:/usr/lib/llvm/20/bin
